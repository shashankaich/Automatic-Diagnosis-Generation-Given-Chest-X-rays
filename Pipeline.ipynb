# %% [markdown]
# # Automatic Diagnosis Generation Given Chest X-rays ML Pipeline

# %%
# mounting drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
drive_path = '/content/gdrive/My Drive/Assignments_Drive/Case_Study_2/Medical_Data'
# specifying paths
txt_path = drive_path + '/ecgen'
img_path = drive_path + '/images'
# add path to system
import sys
sys.path.append(drive_path + '/modules')
# Out:
# Mounted at /content/gdrive

# %%
from IPython.display import Javascript
display(Javascript('IPython.notebook.execute_cells_below()'))
import warnings
warnings.filterwarnings('ignore')

# %%
import model
# This function will return the model
encoder1, encoder2, decoder = model.get_model()
# Out:
# Mounted at /content/gdrive
# 0.22.2.post1
# 2.3.0

# %%
import training
# This function will train the model
encoder1, encoder2, decoder = training.train_model(encoder1, encoder2, decoder, EPOCHS=250)
# Out:
# Mounted at /content/gdrive
# 0.22.2.post1
# 2.3.0
# WARNING:tensorflow:Layer encoder__xray is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer encoder__xray_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Epoch 1 Training Loss 0.728521
# Time taken for 1 epoch 44.701226234436035 sec
#
# Epoch 2 Training Loss 0.667814
# Time taken for 1 epoch 2.3858845233917236 sec
#
# Epoch 3 Training Loss 0.622456
# Time taken for 1 epoch 2.3239336013793945 sec
#
# Epoch 4 Training Loss 0.582915
# Time taken for 1 epoch 2.3056328296661377 sec
#
# Epoch 5 Training Loss 0.550713
# Time taken for 1 epoch 2.29807710647583 sec
#
# Epoch 6 Training Loss 0.524119
# Time taken for 1 epoch 2.3029534816741943 sec
#
# Epoch 7 Training Loss 0.502060
# Time taken for 1 epoch 2.3160040378570557 sec
#
# Epoch 8 Training Loss 0.483747
# Time taken for 1 epoch 2.3056421279907227 sec
#
# Epoch 9 Training Loss 0.467926
# Time taken for 1 epoch 2.3083837032318115 sec
#
# Epoch 10 Training Loss 0.454417
# Time taken for 1 epoch 2.349682331085205 sec
#
# Epoch 11 Training Loss 0.442468
# Time taken for 1 epoch 2.335822820663452 sec
#
# Epoch 12 Training Loss 0.431867
# Time taken for 1 epoch 2.3109636306762695 sec
#
# Epoch 13 Training Loss 0.421979
# Time taken for 1 epoch 2.3667688369750977 sec
#
# Epoch 14 Training Loss 0.413050
# Time taken for 1 epoch 2.331857919692993 sec
#
# Epoch 15 Training Loss 0.404871
# Time taken for 1 epoch 2.312694787979126 sec
#
# Epoch 16 Training Loss 0.397268
# Time taken for 1 epoch 2.3739750385284424 sec
#
# Epoch 17 Training Loss 0.390208
# Time taken for 1 epoch 2.3911008834838867 sec
#
# Epoch 18 Training Loss 0.383600
# Time taken for 1 epoch 2.325721502304077 sec
#
# Epoch 19 Training Loss 0.377630
# Time taken for 1 epoch 2.330934524536133 sec
#
# Epoch 20 Training Loss 0.371938
# Time taken for 1 epoch 2.3454082012176514 sec
#
# Epoch 21 Training Loss 0.366676
# Time taken for 1 epoch 2.340020179748535 sec
#
# Epoch 22 Training Loss 0.361723
# Time taken for 1 epoch 2.3278424739837646 sec
#
# Epoch 23 Training Loss 0.356935
# Time taken for 1 epoch 2.4152650833129883 sec
#
# Epoch 24 Training Loss 0.352379
# Time taken for 1 epoch 2.3484156131744385 sec
#
# Epoch 25 Training Loss 0.347976
# Time taken for 1 epoch 2.348991870880127 sec
#
# Epoch 26 Training Loss 0.343705
# Time taken for 1 epoch 2.3451128005981445 sec
#
# Epoch 27 Training Loss 0.339698
# Time taken for 1 epoch 2.3646440505981445 sec
#
# Epoch 28 Training Loss 0.335883
# Time taken for 1 epoch 2.3446052074432373 sec
#
# Epoch 29 Training Loss 0.332115
# Time taken for 1 epoch 2.375732898712158 sec
#
# Epoch 30 Training Loss 0.328459
# Time taken for 1 epoch 2.3276140689849854 sec
#
# Epoch 31 Training Loss 0.324958
# Time taken for 1 epoch 2.338890790939331 sec
#
# Epoch 32 Training Loss 0.321635
# Time taken for 1 epoch 2.336517333984375 sec
#
# Epoch 33 Training Loss 0.318390
# Time taken for 1 epoch 2.3533742427825928 sec
#
# Epoch 34 Training Loss 0.315307
# Time taken for 1 epoch 2.3385047912597656 sec
#
# Epoch 35 Training Loss 0.312369
# Time taken for 1 epoch 2.332094430923462 sec
#
# Epoch 36 Training Loss 0.309583
# Time taken for 1 epoch 2.315659523010254 sec
#
# Epoch 37 Training Loss 0.306821
# Time taken for 1 epoch 2.3847999572753906 sec
#
# Epoch 38 Training Loss 0.304196
# Time taken for 1 epoch 2.3770861625671387 sec
#
# Epoch 39 Training Loss 0.301634
# Time taken for 1 epoch 2.3386101722717285 sec
#
# Epoch 40 Training Loss 0.299137
# Time taken for 1 epoch 2.3399486541748047 sec
#
# Epoch 41 Training Loss 0.296674
# Time taken for 1 epoch 2.330623149871826 sec
#
# Epoch 42 Training Loss 0.294289
# Time taken for 1 epoch 2.322017192840576 sec
#
# Epoch 43 Training Loss 0.291978
# Time taken for 1 epoch 2.3160698413848877 sec
#
# Epoch 44 Training Loss 0.289837
# Time taken for 1 epoch 2.331047534942627 sec
#
# Epoch 45 Training Loss 0.287758
# Time taken for 1 epoch 2.340808629989624 sec
#
# Epoch 46 Training Loss 0.285740
# Time taken for 1 epoch 2.313537836074829 sec
#
# Epoch 47 Training Loss 0.283756
# Time taken for 1 epoch 2.2951908111572266 sec
#
# Epoch 48 Training Loss 0.281799
# Time taken for 1 epoch 2.314753293991089 sec
#
# Epoch 49 Training Loss 0.279889
# Time taken for 1 epoch 2.3104190826416016 sec
#
# Epoch 50 Training Loss 0.278083
# Time taken for 1 epoch 2.342055082321167 sec
#
# Epoch 51 Training Loss 0.276309
# Time taken for 1 epoch 2.3585386276245117 sec
#
# Epoch 52 Training Loss 0.274576
# Time taken for 1 epoch 2.3899545669555664 sec
#
# Epoch 53 Training Loss 0.272879
# Time taken for 1 epoch 2.3368492126464844 sec
#
# Epoch 54 Training Loss 0.271235
# Time taken for 1 epoch 2.386770486831665 sec
#
# Epoch 55 Training Loss 0.269623
# Time taken for 1 epoch 2.3682103157043457 sec
#
# Epoch 56 Training Loss 0.268137
# Time taken for 1 epoch 2.3598103523254395 sec
#
# Epoch 57 Training Loss 0.266653
# Time taken for 1 epoch 2.392943859100342 sec
#
# Epoch 58 Training Loss 0.265182
# Time taken for 1 epoch 2.3978028297424316 sec
#
# Epoch 59 Training Loss 0.263737
# Time taken for 1 epoch 2.3726043701171875 sec
#
# Epoch 60 Training Loss 0.262334
# Time taken for 1 epoch 2.3233649730682373 sec
#
# Epoch 61 Training Loss 0.260977
# Time taken for 1 epoch 2.365525245666504 sec
#
# Epoch 62 Training Loss 0.259676
# Time taken for 1 epoch 2.353715181350708 sec
#
# Epoch 63 Training Loss 0.258421
# Time taken for 1 epoch 2.3512840270996094 sec
#
# Epoch 64 Training Loss 0.257182
# Time taken for 1 epoch 2.3069024085998535 sec
#
# Epoch 65 Training Loss 0.255968
# Time taken for 1 epoch 2.327272653579712 sec
#
# Epoch 66 Training Loss 0.254780
# Time taken for 1 epoch 2.325726270675659 sec
#
# Epoch 67 Training Loss 0.253601
# Time taken for 1 epoch 2.3311800956726074 sec
#
# Epoch 68 Training Loss 0.252764
# Time taken for 1 epoch 2.3381855487823486 sec
#
# Epoch 69 Training Loss 0.251898
# Time taken for 1 epoch 2.3644204139709473 sec
#
# Epoch 70 Training Loss 0.250910
# Time taken for 1 epoch 2.404425621032715 sec
#
# Epoch 71 Training Loss 0.249907
# Time taken for 1 epoch 2.3401591777801514 sec
#
# Epoch 72 Training Loss 0.248884
# Time taken for 1 epoch 2.3435685634613037 sec
#
# Epoch 73 Training Loss 0.247941
# Time taken for 1 epoch 2.3548624515533447 sec
#
# Epoch 74 Training Loss 0.246988
# Time taken for 1 epoch 2.318033218383789 sec
#
# Epoch 75 Training Loss 0.246025
# Time taken for 1 epoch 2.330967664718628 sec
#
# Epoch 76 Training Loss 0.245025
# Time taken for 1 epoch 2.3688995838165283 sec
#
# Epoch 77 Training Loss 0.244042
# Time taken for 1 epoch 2.3258373737335205 sec
#
# Epoch 78 Training Loss 0.243068
# Time taken for 1 epoch 2.3382983207702637 sec
#
# Epoch 79 Training Loss 0.242127
# Time taken for 1 epoch 2.358684539794922 sec
#
# Epoch 80 Training Loss 0.241197
# Time taken for 1 epoch 2.3377349376678467 sec
#
# Epoch 81 Training Loss 0.240284
# Time taken for 1 epoch 2.3677234649658203 sec
#
# Epoch 82 Training Loss 0.239388
# Time taken for 1 epoch 2.324033737182617 sec
#
# Epoch 83 Training Loss 0.238508
# Time taken for 1 epoch 2.32635498046875 sec
#
# Epoch 84 Training Loss 0.237769
# Time taken for 1 epoch 2.3613312244415283 sec
#
# Epoch 85 Training Loss 0.237031
# Time taken for 1 epoch 2.375143527984619 sec
#
# Epoch 86 Training Loss 0.236283
# Time taken for 1 epoch 2.3100204467773438 sec
#
# Epoch 87 Training Loss 0.235536
# Time taken for 1 epoch 2.355161428451538 sec
#
# Epoch 88 Training Loss 0.234772
# Time taken for 1 epoch 2.3854146003723145 sec
#
# Epoch 89 Training Loss 0.234020
# Time taken for 1 epoch 2.4112837314605713 sec
#
# Epoch 90 Training Loss 0.233267
# Time taken for 1 epoch 2.333104372024536 sec
#
# Epoch 91 Training Loss 0.232510
# Time taken for 1 epoch 2.313687801361084 sec
#
# Epoch 92 Training Loss 0.231768
# Time taken for 1 epoch 2.315275192260742 sec
#
# Epoch 93 Training Loss 0.231049
# Time taken for 1 epoch 2.3754496574401855 sec
#
# Epoch 94 Training Loss 0.230344
# Time taken for 1 epoch 2.3137855529785156 sec
#
# Epoch 95 Training Loss 0.229673
# Time taken for 1 epoch 2.321784019470215 sec
#
# Epoch 96 Training Loss 0.229001
# Time taken for 1 epoch 2.355926752090454 sec
#
# Epoch 97 Training Loss 0.228324
# Time taken for 1 epoch 2.3283097743988037 sec
#
# Epoch 98 Training Loss 0.227672
# Time taken for 1 epoch 2.345168113708496 sec
#
# Epoch 99 Training Loss 0.227062
# Time taken for 1 epoch 2.349966049194336 sec
#
# Epoch 100 Training Loss 0.226484
# Time taken for 1 epoch 2.3544859886169434 sec
#
# Epoch 101 Training Loss 0.225899
# Time taken for 1 epoch 2.383329153060913 sec
#
# Epoch 102 Training Loss 0.225309
# Time taken for 1 epoch 2.3189423084259033 sec
#
# Epoch 103 Training Loss 0.224714
# Time taken for 1 epoch 2.3104336261749268 sec
#
# Epoch 104 Training Loss 0.224111
# Time taken for 1 epoch 2.3628108501434326 sec
#
# Epoch 105 Training Loss 0.223512
# Time taken for 1 epoch 2.4168386459350586 sec
#
# Epoch 106 Training Loss 0.222906
# Time taken for 1 epoch 2.324312686920166 sec
#
# Epoch 107 Training Loss 0.222314
# Time taken for 1 epoch 2.3297693729400635 sec
#
# Epoch 108 Training Loss 0.221729
# Time taken for 1 epoch 2.309011697769165 sec
#
# Epoch 109 Training Loss 0.221144
# Time taken for 1 epoch 2.371328353881836 sec
#
# Epoch 110 Training Loss 0.220561
# Time taken for 1 epoch 2.3440210819244385 sec
#
# Epoch 111 Training Loss 0.219992
# Time taken for 1 epoch 2.3226077556610107 sec
#
# Epoch 112 Training Loss 0.219446
# Time taken for 1 epoch 2.327284574508667 sec
#
# Epoch 113 Training Loss 0.218898
# Time taken for 1 epoch 2.3559908866882324 sec
#
# Epoch 114 Training Loss 0.218333
# Time taken for 1 epoch 2.3617007732391357 sec
#
# Epoch 115 Training Loss 0.217789
# Time taken for 1 epoch 2.3170008659362793 sec
#
# Epoch 116 Training Loss 0.217264
# Time taken for 1 epoch 2.316725254058838 sec
#
# Epoch 117 Training Loss 0.216766
# Time taken for 1 epoch 2.2996110916137695 sec
#
# Epoch 118 Training Loss 0.216275
# Time taken for 1 epoch 2.341102123260498 sec
#
# Epoch 119 Training Loss 0.215795
# Time taken for 1 epoch 2.3274056911468506 sec
#
# Epoch 120 Training Loss 0.215321
# Time taken for 1 epoch 2.309800148010254 sec
#
# Epoch 121 Training Loss 0.214861
# Time taken for 1 epoch 2.3569176197052 sec
#
# Epoch 122 Training Loss 0.214409
# Time taken for 1 epoch 2.360625743865967 sec
#
# Epoch 123 Training Loss 0.213974
# Time taken for 1 epoch 2.303006887435913 sec
#
# Epoch 124 Training Loss 0.213541
# Time taken for 1 epoch 2.3084511756896973 sec
#
# Epoch 125 Training Loss 0.213095
# Time taken for 1 epoch 2.3412792682647705 sec
#
# Epoch 126 Training Loss 0.212629
# Time taken for 1 epoch 2.3555054664611816 sec
#
# Epoch 127 Training Loss 0.212175
# Time taken for 1 epoch 2.3610243797302246 sec
#
# Epoch 128 Training Loss 0.211726
# Time taken for 1 epoch 2.334754705429077 sec
#
# Epoch 129 Training Loss 0.211274
# Time taken for 1 epoch 2.3182156085968018 sec
#
# Epoch 130 Training Loss 0.210828
# Time taken for 1 epoch 2.346674919128418 sec
#
# Epoch 131 Training Loss 0.210481
# Time taken for 1 epoch 2.306720733642578 sec
#
# Epoch 132 Training Loss 0.210098
# Time taken for 1 epoch 2.30989670753479 sec
#
# Epoch 133 Training Loss 0.209708
# Time taken for 1 epoch 2.3139564990997314 sec
#
# Epoch 134 Training Loss 0.209297
# Time taken for 1 epoch 2.351515054702759 sec
#
# Epoch 135 Training Loss 0.208883
# Time taken for 1 epoch 2.3530006408691406 sec
#
# Epoch 136 Training Loss 0.208465
# Time taken for 1 epoch 2.3143699169158936 sec
#
# Epoch 137 Training Loss 0.208048
# Time taken for 1 epoch 2.3374135494232178 sec
#
# Epoch 138 Training Loss 0.207631
# Time taken for 1 epoch 2.357218027114868 sec
#
# Epoch 139 Training Loss 0.207239
# Time taken for 1 epoch 2.3519797325134277 sec
#
# Epoch 140 Training Loss 0.206847
# Time taken for 1 epoch 2.355501413345337 sec
#
# Epoch 141 Training Loss 0.206450
# Time taken for 1 epoch 2.3378734588623047 sec
#
# Epoch 142 Training Loss 0.206054
# Time taken for 1 epoch 2.3652851581573486 sec
#
# Epoch 143 Training Loss 0.205655
# Time taken for 1 epoch 2.3072092533111572 sec
#
# Epoch 144 Training Loss 0.205261
# Time taken for 1 epoch 2.327451229095459 sec
#
# Epoch 145 Training Loss 0.204899
# Time taken for 1 epoch 2.36279559135437 sec
#
# Epoch 146 Training Loss 0.204560
# Time taken for 1 epoch 2.334902048110962 sec
#
# Epoch 147 Training Loss 0.204220
# Time taken for 1 epoch 2.3295321464538574 sec
#
# Epoch 148 Training Loss 0.203878
# Time taken for 1 epoch 2.3617284297943115 sec
#
# Epoch 149 Training Loss 0.203532
# Time taken for 1 epoch 2.31087064743042 sec
#
# Epoch 150 Training Loss 0.203171
# Time taken for 1 epoch 2.3255646228790283 sec
#
# Epoch 151 Training Loss 0.202815
# Time taken for 1 epoch 2.32142972946167 sec
#
# Epoch 152 Training Loss 0.202464
# Time taken for 1 epoch 2.3529765605926514 sec
#
# Epoch 153 Training Loss 0.202122
# Time taken for 1 epoch 2.400184392929077 sec
#
# Epoch 154 Training Loss 0.201788
# Time taken for 1 epoch 2.392252206802368 sec
#
# Epoch 155 Training Loss 0.201463
# Time taken for 1 epoch 2.342440366744995 sec
#
# Epoch 156 Training Loss 0.201151
# Time taken for 1 epoch 2.3134138584136963 sec
#
# Epoch 157 Training Loss 0.200826
# Time taken for 1 epoch 2.356093645095825 sec
#
# Epoch 158 Training Loss 0.200506
# Time taken for 1 epoch 2.3215482234954834 sec
#
# Epoch 159 Training Loss 0.200191
# Time taken for 1 epoch 2.3471100330352783 sec
#
# Epoch 160 Training Loss 0.199920
# Time taken for 1 epoch 2.389861822128296 sec
#
# Epoch 161 Training Loss 0.199666
# Time taken for 1 epoch 2.32568097114563 sec
#
# Epoch 162 Training Loss 0.199402
# Time taken for 1 epoch 2.3284084796905518 sec
#
# Epoch 163 Training Loss 0.199137
# Time taken for 1 epoch 2.2772605419158936 sec
#
# Epoch 164 Training Loss 0.198861
# Time taken for 1 epoch 2.293489694595337 sec
#
# Epoch 165 Training Loss 0.198575
# Time taken for 1 epoch 2.2825846672058105 sec
#
# Epoch 166 Training Loss 0.198291
# Time taken for 1 epoch 2.286381483078003 sec
#
# Epoch 167 Training Loss 0.198019
# Time taken for 1 epoch 2.327873706817627 sec
#
# Epoch 168 Training Loss 0.197745
# Time taken for 1 epoch 2.3630106449127197 sec
#
# Epoch 169 Training Loss 0.197462
# Time taken for 1 epoch 2.3804502487182617 sec
#
# Epoch 170 Training Loss 0.197193
# Time taken for 1 epoch 2.354943037033081 sec
#
# Epoch 171 Training Loss 0.196914
# Time taken for 1 epoch 2.3110899925231934 sec
#
# Epoch 172 Training Loss 0.196642
# Time taken for 1 epoch 2.2961583137512207 sec
#
# Epoch 173 Training Loss 0.196364
# Time taken for 1 epoch 2.3004837036132812 sec
#
# Epoch 174 Training Loss 0.196092
# Time taken for 1 epoch 2.285358428955078 sec
#
# Epoch 175 Training Loss 0.195823
# Time taken for 1 epoch 2.3042068481445312 sec
#
# Epoch 176 Training Loss 0.195546
# Time taken for 1 epoch 2.3606090545654297 sec
#
# Epoch 177 Training Loss 0.195277
# Time taken for 1 epoch 2.3049886226654053 sec
#
# Epoch 178 Training Loss 0.195011
# Time taken for 1 epoch 2.328587770462036 sec
#
# Epoch 179 Training Loss 0.194758
# Time taken for 1 epoch 2.330754518508911 sec
#
# Epoch 180 Training Loss 0.194502
# Time taken for 1 epoch 2.285149097442627 sec
#
# Epoch 181 Training Loss 0.194243
# Time taken for 1 epoch 2.2931132316589355 sec
#
# Epoch 182 Training Loss 0.193992
# Time taken for 1 epoch 2.275975227355957 sec
#
# Epoch 183 Training Loss 0.193775
# Time taken for 1 epoch 2.308675527572632 sec
#
# Epoch 184 Training Loss 0.193559
# Time taken for 1 epoch 2.2863590717315674 sec
#
# Epoch 185 Training Loss 0.193348
# Time taken for 1 epoch 2.3554527759552 sec
#
# Epoch 186 Training Loss 0.193130
# Time taken for 1 epoch 2.3665947914123535 sec
#
# Epoch 187 Training Loss 0.192909
# Time taken for 1 epoch 2.3453807830810547 sec
#
# Epoch 188 Training Loss 0.192687
# Time taken for 1 epoch 2.330148935317993 sec
#
# Epoch 189 Training Loss 0.192479
# Time taken for 1 epoch 2.309413433074951 sec
#
# Epoch 190 Training Loss 0.192278
# Time taken for 1 epoch 2.308591604232788 sec
#
# Epoch 191 Training Loss 0.192107
# Time taken for 1 epoch 2.287210702896118 sec
#
# Epoch 192 Training Loss 0.191949
# Time taken for 1 epoch 2.3603341579437256 sec
#
# Epoch 193 Training Loss 0.191788
# Time taken for 1 epoch 2.299565315246582 sec
#
# Epoch 194 Training Loss 0.191645
# Time taken for 1 epoch 2.3027071952819824 sec
#
# Epoch 195 Training Loss 0.191477
# Time taken for 1 epoch 2.3421742916107178 sec
#
# Epoch 196 Training Loss 0.191306
# Time taken for 1 epoch 2.320349931716919 sec
#
# Epoch 197 Training Loss 0.191132
# Time taken for 1 epoch 2.309335947036743 sec
#
# Epoch 198 Training Loss 0.190945
# Time taken for 1 epoch 2.32525634765625 sec
#
# Epoch 199 Training Loss 0.190777
# Time taken for 1 epoch 2.3280396461486816 sec
#
# Epoch 200 Training Loss 0.190591
# Time taken for 1 epoch 2.2895348072052 sec
#
# Epoch 201 Training Loss 0.190410
# Time taken for 1 epoch 2.3249311447143555 sec
#
# Epoch 202 Training Loss 0.190214
# Time taken for 1 epoch 2.3152592182159424 sec
#
# Epoch 203 Training Loss 0.190016
# Time taken for 1 epoch 2.288674831390381 sec
#
# Epoch 204 Training Loss 0.189816
# Time taken for 1 epoch 2.2890169620513916 sec
#
# Epoch 205 Training Loss 0.189611
# Time taken for 1 epoch 2.319467782974243 sec
#
# Epoch 206 Training Loss 0.189410
# Time taken for 1 epoch 2.2855865955352783 sec
#
# Epoch 207 Training Loss 0.189202
# Time taken for 1 epoch 2.3177528381347656 sec
#
# Epoch 208 Training Loss 0.189000
# Time taken for 1 epoch 2.3131420612335205 sec
#
# Epoch 209 Training Loss 0.188794
# Time taken for 1 epoch 2.3227908611297607 sec
#
# Epoch 210 Training Loss 0.188591
# Time taken for 1 epoch 2.2694380283355713 sec
#
# Epoch 211 Training Loss 0.188413
# Time taken for 1 epoch 2.303037405014038 sec
#
# Epoch 212 Training Loss 0.188245
# Time taken for 1 epoch 2.292128562927246 sec
#
# Epoch 213 Training Loss 0.188062
# Time taken for 1 epoch 2.3115463256835938 sec
#
# Epoch 214 Training Loss 0.187869
# Time taken for 1 epoch 2.313272714614868 sec
#
# Epoch 215 Training Loss 0.187676
# Time taken for 1 epoch 2.2966575622558594 sec
#
# Epoch 216 Training Loss 0.187477
# Time taken for 1 epoch 2.269803762435913 sec
#
# Epoch 217 Training Loss 0.187276
# Time taken for 1 epoch 2.2753827571868896 sec
#
# Epoch 218 Training Loss 0.187071
# Time taken for 1 epoch 2.3586599826812744 sec
#
# Epoch 219 Training Loss 0.186864
# Time taken for 1 epoch 2.322374105453491 sec
#
# Epoch 220 Training Loss 0.186657
# Time taken for 1 epoch 2.288937568664551 sec
#
# Epoch 221 Training Loss 0.186453
# Time taken for 1 epoch 2.3383123874664307 sec
#
# Epoch 222 Training Loss 0.186251
# Time taken for 1 epoch 2.3167810440063477 sec
#
# Epoch 223 Training Loss 0.186059
# Time taken for 1 epoch 2.293264150619507 sec
#
# Epoch 224 Training Loss 0.185877
# Time taken for 1 epoch 2.3641669750213623 sec
#
# Epoch 225 Training Loss 0.185699
# Time taken for 1 epoch 2.3061695098876953 sec
#
# Epoch 226 Training Loss 0.185530
# Time taken for 1 epoch 2.3217899799346924 sec
#
# Epoch 227 Training Loss 0.185361
# Time taken for 1 epoch 2.3202896118164062 sec
#
# Epoch 228 Training Loss 0.185216
# Time taken for 1 epoch 2.294124126434326 sec
#
# Epoch 229 Training Loss 0.185072
# Time taken for 1 epoch 2.3275630474090576 sec
#
# Epoch 230 Training Loss 0.184915
# Time taken for 1 epoch 2.3378708362579346 sec
#
# Epoch 231 Training Loss 0.184762
# Time taken for 1 epoch 2.3060014247894287 sec
#
# Epoch 232 Training Loss 0.184602
# Time taken for 1 epoch 2.299105405807495 sec
#
# Epoch 233 Training Loss 0.184528
# Time taken for 1 epoch 2.340609550476074 sec
#
# Epoch 234 Training Loss 0.184457
# Time taken for 1 epoch 2.291499376296997 sec
#
# Epoch 235 Training Loss 0.184411
# Time taken for 1 epoch 2.3138248920440674 sec
#
# Epoch 236 Training Loss 0.184795
# Time taken for 1 epoch 2.3134493827819824 sec
#
# Epoch 237 Training Loss 0.185048
# Time taken for 1 epoch 2.2974514961242676 sec
#
# Epoch 238 Training Loss 0.185236
# Time taken for 1 epoch 2.285679340362549 sec
#
# Epoch 239 Training Loss 0.185366
# Time taken for 1 epoch 2.3270297050476074 sec
#
# Epoch 240 Training Loss 0.185445
# Time taken for 1 epoch 2.301598310470581 sec
#
# Epoch 241 Training Loss 0.185504
# Time taken for 1 epoch 2.290426254272461 sec
#
# Epoch 242 Training Loss 0.185543
# Time taken for 1 epoch 2.273679256439209 sec
#
# Epoch 243 Training Loss 0.185560
# Time taken for 1 epoch 2.328089952468872 sec
#
# Epoch 244 Training Loss 0.185547
# Time taken for 1 epoch 2.2913339138031006 sec
#
# Epoch 245 Training Loss 0.185516
# Time taken for 1 epoch 2.2980899810791016 sec
#
# Epoch 246 Training Loss 0.185474
# Time taken for 1 epoch 2.330415964126587 sec
#
# Epoch 247 Training Loss 0.185421
# Time taken for 1 epoch 2.3670969009399414 sec
#
# Epoch 248 Training Loss 0.185359
# Time taken for 1 epoch 2.320712089538574 sec
#
# Epoch 249 Training Loss 0.185282
# Time taken for 1 epoch 2.3130531311035156 sec
#
# Epoch 250 Training Loss 0.185199
# Time taken for 1 epoch 2.299344301223755 sec
#
# Train BLEU score 0.462322
# Test BLEU score 0.450414

# %%
import inference
# This function will take a random image pair and print results
inference.generate_sample_impression(encoder1, encoder2, decoder)
# Out:
# --------------------------------------------------Front X-Ray--------------------------------------------------
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x420 at 0x7F184FE1CF60>
# --------------------------------------------------Lateral X-Ray--------------------------------------------------
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x624 at 0x7F184FE6F5C0>
# --------------------------------------------------GREEDY_SEARCH--------------------------------------------------
# Actual Impression  ['<start> No acute cardiopulmonary abnormality. <end>']
# Generated Impression  ['<start>', 'no', 'evidence', 'of', 'pneumothora', '<end>']
# BLEU Score for Greedy search is  0.5623413251903491
# --------------------------------------------------BEAM_SEARCH--------------------------------------------------
# Actual Impression  ['<start> No acute cardiopulmonary abnormality. <end>']
# Generated Impression  ['<start>', 'no', 'radiographic', 'evidence', 'of', 'pneumothora', 'stable', 'appearance', '<end>']
# BLEU Score for Beam search is  0.45180100180492244

# %% [markdown]
# ## Conclusions

# %% [markdown]
# - In this Notebook we implimented the entire ML Pipeline in Python Modules.
# - The generate_sample_impression function generates a random sample and prints the results.
# - The pretrained ML Model can be used but, in this notebook we trained the model  and generated the results.

# %% [markdown]
# ## References
#
# - https://www.tensorflow.org/tutorials/text/image_captioning#model
# - https://www.tensorflow.org/tutorials/text/nmt_with_attention#write_the_encoder_and_decoder_model
# - https://stackoverflow.com/questions/50786987/multiclass-classification-to-balance-in-python-over-sampling
# - https://radimrehurek.com/gensim/models/word2vec.html
# - https://machinelearningmastery.com/develop-word-embeddings-python-gensim/
# - https://machinelearningmastery.com/calculate-bleu-score-for-text-python/
# - https://github.com/nagapavan525/radiology-report-generation/blob/master/radiology_report_generation_final/Automated_Radiology_Report_Generation_attention%20(1).ipynb
# - https://github.com/nagapavan525/radiology-report-generation/blob/master/NewIntegrationWithIndication/1_Capstone-Radiology-PreProcessing.ipynb
# - https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# - https://stackoverflow.com/questions/2612548/extracting-an-attribute-value-with-beautifulsoup
# - https://stackoverflow.com/questions/24962673/beautiful-soup-getting-tag-id
# - https://stackoverflow.com/a/47091490/4084039
# - https://www.appservgrid.com/psam/Python_Samplifier--python1compute--Python_Program_to_Find_the_Size_(Resolution)_of_a_Image.html
# - https://www.geeksforgeeks.org/working-images-python/
# - https://gist.github.com/sebleier/554280
# - https://stackoverflow.com/questions/27488446/how-do-i-get-word-frequency-in-a-corpus-using-scikit-learn-countvectorizer
# - https://www.geeksforgeeks.org/python-remove-all-digits-from-a-list-of-strings/
# - https://stackoverflow.com/questions/12851791/removing-numbers-from-string
# - https://github.com/nagapavan525/radiology-report-generation/blob/master/radiology_report_generation_final/AutomatedRadiologyReportGenerationWithSentenceEmbeddings.ipynb
# - https://machinelearningmastery.com/develop-a-deep-learning-caption-generation-model-in-python/
